# %%
import json
import pandas as pd
import plotly.graph_objects as go
from dash import Dash, html, dcc
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output, State
import websocket
import threading
import time
import socket

# Create the Dash App
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

symbol_dropdown = html.Div([
    html.P('Symbol:'),
    dcc.Dropdown(
        id='symbol-dropdown',
        options=[{'label': 'BTC/USDT', 'value': 'btcusdt'}],
        value='btcusdt'
    )
])

timeframe_dropdown = html.Div([
    html.P('Timeframe:'),
    dcc.Dropdown(
        id='timeframe-dropdown',
        options=[{'label': '1m', 'value': '1m'}, {'label': '5m', 'value': '5m'}, {'label': '15m', 'value': '15m'}],
        value='1m'
    )
])

num_bars_input = html.Div([
    html.P('Number of Candles'),
    dbc.Input(id='num-bar-input', type='number', value='1000')
])

# Create the layout of the App
app.layout = html.Div([
    html.H1('Real Time Charts'),

    dbc.Row([
        dbc.Col(symbol_dropdown),
        dbc.Col(timeframe_dropdown),
        dbc.Col(num_bars_input)
    ]),

    html.Hr(),

    dcc.Interval(id='update', interval=1000),

    html.Div(id='page-content')

], style={'margin-left': '5%', 'margin-right': '5%', 'margin-top': '20px'})


# WebSocket setup
ws_data = []

def on_message(ws, message):
    global ws_data
    json_message = json.loads(message)
    kline = json_message['k']
    candle = {
        'time': pd.to_datetime(kline['t'], unit='ms'),
        'open': float(kline['o']),
        'high': float(kline['h']),
        'low': float(kline['l']),
        'close': float(kline['c'])
    }
    ws_data.append(candle)
    ws_data = ws_data[-1000:]  # Keep only the last 1000 candles

def on_error(ws, error):
    print("WebSocket error:", error)

def on_close(ws, close_status_code, close_msg):
    print("WebSocket closed with code:", close_status_code, "message:", close_msg)
    print("Reconnecting...")
    time.sleep(5)  # Wait for 5 seconds before reconnecting
    start_websocket()

def on_open(ws):
    print("WebSocket connection opened")
    ws.send(json.dumps({
        "method": "SUBSCRIBE",
        "params": [
            "btcusdt@kline_1m"
        ],
        "id": 1
    }))

def start_websocket():
    while True:
        try:
            ws = websocket.WebSocketApp("wss://stream.binance.com:9443/ws",
                                        on_open=on_open,
                                        on_message=on_message,
                                        on_error=on_error,
                                        on_close=on_close)
            ws.run_forever()
        except socket.gaierror as e:
            print("Socket error:", e)
            time.sleep(5)  # Wait before retrying
        except Exception as e:
            print("Unexpected error:", e)
            time.sleep(5)  # Wait before retrying

# Start the WebSocket in a separate thread
ws_thread = threading.Thread(target=start_websocket)
ws_thread.start()


@app.callback(
    Output('page-content', 'children'),
    Input('update', 'n_intervals'),
    Input('symbol-dropdown', 'value'),
    State('timeframe-dropdown', 'value'), State('num-bar-input', 'value')
)
def update_ohlc_chart(interval, symbol, timeframe, num_bars):
    num_bars = int(num_bars)
    df = pd.DataFrame(ws_data)

    if df.empty:
        return [html.H2(id='chart-details', children='Waiting for data...')]

    # Calculate Heikin Ashi candles
    heikin_ashi_df = calculate_heikin_ashi(df)
    heikin_ashi_df = heikin_ashi_df.tail(num_bars)

    # Calculate SSL Strategy
    ssl_df = calculate_ssl_strategy(heikin_ashi_df)
    
    # Calculate 20-period EMA
    ssl_df['ema_20'] = ssl_df['HA_Close'].ewm(span=20, adjust=False).mean()
    
    fig = go.Figure(data=go.Candlestick(x=ssl_df['time'],
                                        open=ssl_df['HA_Open'],
                                        high=ssl_df['HA_High'],
                                        low=ssl_df['HA_Low'],
                                        close=ssl_df['HA_Close'],
                                        increasing_line_color='green', increasing_fillcolor='green',
                                        decreasing_line_color='red', decreasing_fillcolor='red'))

    # Add SSL Up and Down lines
    fig.add_trace(go.Scatter(x=ssl_df['time'], y=ssl_df['sslDown_Smooth2'], mode='lines', line=dict(color='red'), name='SSL Down'))
    fig.add_trace(go.Scatter(x=ssl_df['time'], y=ssl_df['sslUp_Smooth2'], mode='lines', line=dict(color='lime'), name='SSL Up'))
    
    # Add 20-period EMA
    fig.add_trace(go.Scatter(x=ssl_df['time'], y=ssl_df['ema_20'], mode='lines', line=dict(color='black'), name='20 EMA'))

    fig.update(layout_xaxis_rangeslider_visible=False)
    fig.update_layout(yaxis={'side': 'right'})
    fig.layout.xaxis.fixedrange = True
    fig.layout.yaxis.fixedrange = True

    return [
        html.H2(id='chart-details', children=f'{symbol.upper()} - {timeframe}'),
        dcc.Graph(figure=fig, config={'displayModeBar': False})
    ]


def calculate_heikin_ashi(df):
    heikin_ashi_df = df.copy()
    heikin_ashi_df['HA_Close'] = (df['open'] + df['high'] + df['low'] + df['close']) / 4
    heikin_ashi_df['HA_Open'] = 0.0  # Initialize column

    # Set the first HA Open value
    heikin_ashi_df.loc[0, 'HA_Open'] = (df['open'].iloc[0] + df['close'].iloc[0]) / 2

    # Calculate the remaining HA Open values
    for i in range(1, len(df)):
        heikin_ashi_df.loc[i, 'HA_Open'] = (heikin_ashi_df.loc[i - 1, 'HA_Open'] + heikin_ashi_df.loc[i - 1, 'HA_Close']) / 2

    heikin_ashi_df['HA_High'] = heikin_ashi_df[['HA_Open', 'HA_Close', 'high']].max(axis=1)
    heikin_ashi_df['HA_Low'] = heikin_ashi_df[['HA_Open', 'HA_Close', 'low']].min(axis=1)

    return heikin_ashi_df

def calculate_ssl_strategy(df, period=10, smoothing_period=5):  # Increase smoothing period for smoother lines
    df['smaHigh'] = df['HA_High'].rolling(window=period).mean()
    df['smaLow'] = df['HA_Low'].rolling(window=period).mean()
    df['Hlv'] = 0

    for i in range(1, len(df)):
        if df['HA_Close'].iloc[i] > df['smaHigh'].iloc[i]:
            df.at[i, 'Hlv'] = 1
        elif df['HA_Close'].iloc[i] < df['smaLow'].iloc[i]:
            df.at[i, 'Hlv'] = -1
        else:
            df.at[i, 'Hlv'] = df['Hlv'].iloc[i-1]

    df['sslDown'] = df.apply(lambda row: row['smaHigh'] if row['Hlv'] < 0 else row['smaLow'], axis=1)
    df['sslUp'] = df.apply(lambda row: row['smaLow'] if row['Hlv'] < 0 else row['smaHigh'], axis=1)
    
    # Apply EMA smoothing twice for SSL Down
    df['sslDown_Smooth'] = df['sslDown'].ewm(span=smoothing_period, adjust=False).mean()
    df['sslDown_Smooth2'] = df['sslDown_Smooth'].ewm(span=smoothing_period, adjust=False).mean()
    
    # Apply EMA smoothing twice for SSL Up
    df['sslUp_Smooth'] = df['sslUp'].ewm(span=smoothing_period, adjust=False).mean()
    df['sslUp_Smooth2'] = df['sslUp_Smooth'].ewm(span=smoothing_period, adjust=False).mean()
    
    return df

if __name__ == '__main__':
    # Start the Dash server
    app.run_server(debug=True, port=8052)  # Specify a different port here
# Out:
# c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\dash\dash.py:1815: DeprecationWarning:
#
# 'pkgutil.find_loader' is deprecated and slated for removal in Python 3.14; use importlib.util.find_spec() instead
#
# c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\dash\dash.py:1815: DeprecationWarning:
#
# 'pkgutil.find_loader' is deprecated and slated for removal in Python 3.14; use importlib.util.find_spec() instead
# WebSocket connection opened
# WebSocket error: 'k'
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8052/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 122, in update_ohlc_chart(
#     interval=53,
#     symbol='btcusdt',
#     timeframe='1m',
#     num_bars=1000
# )
#     114 @app.callback(
#     115     Output('page-content', 'children'),
#     116     Input('update', 'n_intervals'),
#    (...)
#     119 )
#     120 def update_ohlc_chart(interval, symbol, timeframe, num_bars):
#     121     num_bars = int(num_bars)
# --> 122     df = pd.DataFrame(ws_data)
#         ws_data = [{'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66558.0, 'low': 66531.74, 'close': 66558.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66558.0, 'low': 66531.74, 'close': 66558.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66558.0, 'low': 6653 ...
#         pd = <module 'pandas' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>
#     124     if df.empty:
#     125         return [html.H2(id='chart-details', children='Waiting for data...')]
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:859, in DataFrame.__init__(
#     self=UNRECOVERABLE REPR FAILURE,
#     data=[{'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, ...],
#     index=RangeIndex(start=0, stop=564, step=1),
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     dtype=None,
#     copy=False
# )
#     850         columns = ensure_index(columns)
#     851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     857         dtype,
#     858     )
# --> 859     mgr = arrays_to_mgr(
#         arrays = [array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])]
#         columns = Index(['time', 'open', 'high', 'low', 'close'], dtype='object')
#         index = RangeIndex(start=0, stop=564, step=1)
#         dtype = None
#         manager = 'block'
#     860         arrays,
#     861         columns,
#     862         index,
#     863         dtype=dtype,
#     864         typ=manager,
#     865     )
#     866 else:
#     867     mgr = ndarray_to_mgr(
#     868         data,
#     869         index,
#    (...)
#     873         typ=manager,
#     874     )
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(
#     arrays=[array(['2024-07-20T10:22:00.000000000', '2024-07...:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])],
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     index=RangeIndex(start=0, stop=564, step=1),
#     dtype=None,
#     verify_integrity=True,
#     typ='block',
#     consolidate=True
# )
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#         index = RangeIndex(start=0, stop=564, step=1)
#         arrays = [array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])]
#         dtype = None
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:630, in _homogenize(
#     data=[array(['2024-07-20T10:22:00.000000000', '2024-07...:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])],
#     index=RangeIndex(start=0, stop=564, step=1),
#     dtype=None
# )
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#         val = array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=564, step=1)
#         com = <module 'pandas.core.common' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\core\\common.py'>
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(
#     data=array(['2024-07-20T10:22:00.000000000', '2024-07...:24:00.000000000'],
#       dtype='datetime64[ns]'),
#     index=RangeIndex(start=0, stop=564, step=1)
# )
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#         data = array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=564, step=1)
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (563) does not match length of index (564)
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 122, in update_ohlc_chart(
#     interval=1,
#     symbol='btcusdt',
#     timeframe='1m',
#     num_bars=1000
# )
#     114 @app.callback(
#     115     Output('page-content', 'children'),
#     116     Input('update', 'n_intervals'),
#    (...)
#     119 )
#     120 def update_ohlc_chart(interval, symbol, timeframe, num_bars):
#     121     num_bars = int(num_bars)
# --> 122     df = pd.DataFrame(ws_data)
#         ws_data = [{'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66547.99}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66548.0, 'low': 66531.74, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66558.0, 'low': 66531.74, 'close': 66558.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66558.0, 'low': 66531.74, 'close': 66558.0}, {'time': Timestamp('2024-07-20 10:22:00'), 'open': 66531.75, 'high': 66558.0, 'low': 6653 ...
#         pd = <module 'pandas' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>
#     124     if df.empty:
#     125         return [html.H2(id='chart-details', children='Waiting for data...')]
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:859, in DataFrame.__init__(
#     self=UNRECOVERABLE REPR FAILURE,
#     data=[{'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66547.99, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, {'close': 66548.0, 'high': 66548.0, 'low': 66531.74, 'open': 66531.75, 'time': Timestamp('2024-07-20 10:22:00')}, ...],
#     index=RangeIndex(start=0, stop=612, step=1),
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     dtype=None,
#     copy=False
# )
#     850         columns = ensure_index(columns)
#     851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     857         dtype,
#     858     )
# --> 859     mgr = arrays_to_mgr(
#         arrays = [array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])]
#         columns = Index(['time', 'open', 'high', 'low', 'close'], dtype='object')
#         index = RangeIndex(start=0, stop=612, step=1)
#         dtype = None
#         manager = 'block'
#     860         arrays,
#     861         columns,
#     862         index,
#     863         dtype=dtype,
#     864         typ=manager,
#     865     )
#     866 else:
#     867     mgr = ndarray_to_mgr(
#     868         data,
#     869         index,
#    (...)
#     873         typ=manager,
#     874     )
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(
#     arrays=[array(['2024-07-20T10:22:00.000000000', '2024-07...:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])],
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     index=RangeIndex(start=0, stop=612, step=1),
#     dtype=None,
#     verify_integrity=True,
#     typ='block',
#     consolidate=True
# )
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#         index = RangeIndex(start=0, stop=612, step=1)
#         arrays = [array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])]
#         dtype = None
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:630, in _homogenize(
#     data=[array(['2024-07-20T10:22:00.000000000', '2024-07...:24:00.000000000'],
#       dtype='datetime64[ns]'), array([66531.75, 66531.75, 66531.75, ..., 66534.01, 66534.01, 66534.01]), array([66548.  , 66548.  , 66548.  , ..., 66534.01, 66534.01, 66534.01]), array([66531.74, 66531.74, 66531.74, ..., 66534.  , 66534.  , 66534.  ]), array([66547.99, 66547.99, 66547.99, ..., 66534.  , 66534.  , 66534.  ])],
#     index=RangeIndex(start=0, stop=612, step=1),
#     dtype=None
# )
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#         val = array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=612, step=1)
#         com = <module 'pandas.core.common' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\core\\common.py'>
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(
#     data=array(['2024-07-20T10:22:00.000000000', '2024-07...:24:00.000000000'],
#       dtype='datetime64[ns]'),
#     index=RangeIndex(start=0, stop=612, step=1)
# )
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#         data = array(['2024-07-20T10:22:00.000000000', '2024-07-20T10:22:00.000000000',
#        '2024-07-20T10:22:00.000000000', ..., '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=612, step=1)
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (611) does not match length of index (612)
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 122, in update_ohlc_chart(
#     interval=88,
#     symbol='btcusdt',
#     timeframe='1m',
#     num_bars=1000
# )
#     114 @app.callback(
#     115     Output('page-content', 'children'),
#     116     Input('update', 'n_intervals'),
#    (...)
#     119 )
#     120 def update_ohlc_chart(interval, symbol, timeframe, num_bars):
#     121     num_bars = int(num_bars)
# --> 122     df = pd.DataFrame(ws_data)
#         ws_data = [{'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.01}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:23:00'), 'open': 66578.66, 'high': 66578.66, 'low': 665 ...
#         pd = <module 'pandas' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>
#     124     if df.empty:
#     125         return [html.H2(id='chart-details', children='Waiting for data...')]
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:859, in DataFrame.__init__(
#     self=UNRECOVERABLE REPR FAILURE,
#     data=[{'close': 66534.0, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.0, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.0, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.0, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, {'close': 66534.01, 'high': 66578.66, 'low': 66534.0, 'open': 66578.66, 'time': Timestamp('2024-07-20 10:23:00')}, ...],
#     index=RangeIndex(start=0, stop=1001, step=1),
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     dtype=None,
#     copy=False
# )
#     850         columns = ensure_index(columns)
#     851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     857         dtype,
#     858     )
# --> 859     mgr = arrays_to_mgr(
#         arrays = [array(['2024-07-20T10:23:00.000000000', '2024-07-20T10:23:00.000000000',
#        '2024-07-20T10:23:00.000000000', ..., '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000'],
#       dtype='datetime64[ns]'), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99])]
#         columns = Index(['time', 'open', 'high', 'low', 'close'], dtype='object')
#         index = RangeIndex(start=0, stop=1001, step=1)
#         dtype = None
#         manager = 'block'
#     860         arrays,
#     861         columns,
#     862         index,
#     863         dtype=dtype,
#     864         typ=manager,
#     865     )
#     866 else:
#     867     mgr = ndarray_to_mgr(
#     868         data,
#     869         index,
#    (...)
#     873         typ=manager,
#     874     )
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(
#     arrays=[array(['2024-07-20T10:23:00.000000000', '2024-07...:26:00.000000000'],
#       dtype='datetime64[ns]'), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99])],
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     index=RangeIndex(start=0, stop=1001, step=1),
#     dtype=None,
#     verify_integrity=True,
#     typ='block',
#     consolidate=True
# )
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#         index = RangeIndex(start=0, stop=1001, step=1)
#         arrays = [array(['2024-07-20T10:23:00.000000000', '2024-07-20T10:23:00.000000000',
#        '2024-07-20T10:23:00.000000000', ..., '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000'],
#       dtype='datetime64[ns]'), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99])]
#         dtype = None
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:630, in _homogenize(
#     data=[array(['2024-07-20T10:23:00.000000000', '2024-07...:26:00.000000000'],
#       dtype='datetime64[ns]'), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66578.66, 66578.66, 66578.66, ..., 66542.  , 66542.  , 66542.  ]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99]), array([66534.  , 66534.  , 66534.  , ..., 66541.99, 66541.99, 66541.99])],
#     index=RangeIndex(start=0, stop=1001, step=1),
#     dtype=None
# )
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#         val = array(['2024-07-20T10:23:00.000000000', '2024-07-20T10:23:00.000000000',
#        '2024-07-20T10:23:00.000000000', ..., '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=1001, step=1)
#         com = <module 'pandas.core.common' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\core\\common.py'>
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(
#     data=array(['2024-07-20T10:23:00.000000000', '2024-07...:26:00.000000000'],
#       dtype='datetime64[ns]'),
#     index=RangeIndex(start=0, stop=1001, step=1)
# )
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#         data = array(['2024-07-20T10:23:00.000000000', '2024-07-20T10:23:00.000000000',
#        '2024-07-20T10:23:00.000000000', ..., '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=1001, step=1)
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (1000) does not match length of index (1001)
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 122, in update_ohlc_chart(
#     interval=102,
#     symbol='btcusdt',
#     timeframe='1m',
#     num_bars=1000
# )
#     114 @app.callback(
#     115     Output('page-content', 'children'),
#     116     Input('update', 'n_intervals'),
#    (...)
#     119 )
#     120 def update_ohlc_chart(interval, symbol, timeframe, num_bars):
#     121     num_bars = int(num_bars)
# --> 122     df = pd.DataFrame(ws_data)
#         ws_data = [{'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.01, 'low': 66534.0, 'close': 66534.0}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.02}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03, 'low': 66534.0, 'close': 66534.03}, {'time': Timestamp('2024-07-20 10:24:00'), 'open': 66534.01, 'high': 66534.03,  ...
#         pd = <module 'pandas' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>
#     124     if df.empty:
#     125         return [html.H2(id='chart-details', children='Waiting for data...')]
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:859, in DataFrame.__init__(
#     self=UNRECOVERABLE REPR FAILURE,
#     data=[{'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.0, 'high': 66534.01, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, {'close': 66534.02, 'high': 66534.03, 'low': 66534.0, 'open': 66534.01, 'time': Timestamp('2024-07-20 10:24:00')}, ...],
#     index=RangeIndex(start=0, stop=1001, step=1),
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     dtype=None,
#     copy=False
# )
#     850         columns = ensure_index(columns)
#     851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     857         dtype,
#     858     )
# --> 859     mgr = arrays_to_mgr(
#         arrays = [array(['2024-07-20T10:24:00.000000000', '2024-07-20T10:24:00.000000000',
#        '2024-07-20T10:24:00.000000000', ..., '2024-07-20T10:27:00.000000000',
#        '2024-07-20T10:27:00.000000000', '2024-07-20T10:27:00.000000000'],
# ...
#        '2024-07-20T10:28:00.000000000', '2024-07-20T10:28:00.000000000'],
#       dtype='datetime64[ns]'), array([66542.  , 66542.  , 66542.  , ..., 66540.86, 66540.86, 66540.86]), array([66542.  , 66542.  , 66542.  , ..., 66547.99, 66547.99, 66547.99]), array([66541.99, 66541.99, 66541.99, ..., 66540.85, 66540.85, 66540.85]), array([66541.99, 66541.99, 66541.99, ..., 66547.98, 66547.98, 66547.98])]
#         dtype = None
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:630, in _homogenize(
#     data=[array(['2024-07-20T10:26:00.000000000', '2024-07...:28:00.000000000'],
#       dtype='datetime64[ns]'), array([66542.  , 66542.  , 66542.  , ..., 66540.86, 66540.86, 66540.86]), array([66542.  , 66542.  , 66542.  , ..., 66547.99, 66547.99, 66547.99]), array([66541.99, 66541.99, 66541.99, ..., 66540.85, 66540.85, 66540.85]), array([66541.99, 66541.99, 66541.99, ..., 66547.98, 66547.98, 66547.98])],
#     index=RangeIndex(start=0, stop=1001, step=1),
#     dtype=None
# )
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#         val = array(['2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', ..., '2024-07-20T10:28:00.000000000',
#        '2024-07-20T10:28:00.000000000', '2024-07-20T10:28:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=1001, step=1)
#         com = <module 'pandas.core.common' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\core\\common.py'>
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(
#     data=array(['2024-07-20T10:26:00.000000000', '2024-07...:28:00.000000000'],
#       dtype='datetime64[ns]'),
#     index=RangeIndex(start=0, stop=1001, step=1)
# )
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#         data = array(['2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', ..., '2024-07-20T10:28:00.000000000',
#        '2024-07-20T10:28:00.000000000', '2024-07-20T10:28:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=1001, step=1)
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (1000) does not match length of index (1001)
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 122, in update_ohlc_chart(
#     interval=127,
#     symbol='btcusdt',
#     timeframe='1m',
#     num_bars=1000
# )
#     114 @app.callback(
#     115     Output('page-content', 'children'),
#     116     Input('update', 'n_intervals'),
#    (...)
#     119 )
#     120 def update_ohlc_chart(interval, symbol, timeframe, num_bars):
#     121     num_bars = int(num_bars)
# --> 122     df = pd.DataFrame(ws_data)
#         ws_data = [{'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66542.0, 'low': 66541.99, 'close': 66542.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66548.0, 'low': 66541.99, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66548.0, 'low': 66541.99, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66548.0, 'low': 66541.99, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66548.0, 'low': 66541.99, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66548.0, 'low': 66541.99, 'close': 66548.0}, {'time': Timestamp('2024-07-20 10:26:00'), 'open': 66542.0, 'high': 66548.0, 'low': 66541.99, 'close': 66548.0}, {'time': Timestamp('2024-0 ...
#         pd = <module 'pandas' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>
#     124     if df.empty:
#     125         return [html.H2(id='chart-details', children='Waiting for data...')]
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:859, in DataFrame.__init__(
#     self=UNRECOVERABLE REPR FAILURE,
#     data=[{'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, {'close': 66542.0, 'high': 66542.0, 'low': 66541.99, 'open': 66542.0, 'time': Timestamp('2024-07-20 10:26:00')}, ...],
#     index=RangeIndex(start=0, stop=1001, step=1),
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     dtype=None,
#     copy=False
# )
#     850         columns = ensure_index(columns)
#     851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     857         dtype,
#     858     )
# --> 859     mgr = arrays_to_mgr(
#         arrays = [array(['2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', ..., '2024-07-20T10:29:00.000000000',
#        '2024-07-20T10:29:00.000000000', '2024-07-20T10:29:00.000000000'],
#       dtype='datetime64[ns]'), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.99, 66547.99, 66547.99]), array([66541.99, 66541.99, 66541.99, ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98])]
#         columns = Index(['time', 'open', 'high', 'low', 'close'], dtype='object')
#         index = RangeIndex(start=0, stop=1001, step=1)
#         dtype = None
#         manager = 'block'
#     860         arrays,
#     861         columns,
#     862         index,
#     863         dtype=dtype,
#     864         typ=manager,
#     865     )
#     866 else:
#     867     mgr = ndarray_to_mgr(
#     868         data,
#     869         index,
#    (...)
#     873         typ=manager,
#     874     )
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(
#     arrays=[array(['2024-07-20T10:26:00.000000000', '2024-07...:29:00.000000000'],
#       dtype='datetime64[ns]'), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.99, 66547.99, 66547.99]), array([66541.99, 66541.99, 66541.99, ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98])],
#     columns=Index(['time', 'open', 'high', 'low', 'close'], dtype='object'),
#     index=RangeIndex(start=0, stop=1001, step=1),
#     dtype=None,
#     verify_integrity=True,
#     typ='block',
#     consolidate=True
# )
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#         index = RangeIndex(start=0, stop=1001, step=1)
#         arrays = [array(['2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', ..., '2024-07-20T10:29:00.000000000',
#        '2024-07-20T10:29:00.000000000', '2024-07-20T10:29:00.000000000'],
#       dtype='datetime64[ns]'), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.99, 66547.99, 66547.99]), array([66541.99, 66541.99, 66541.99, ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98])]
#         dtype = None
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:630, in _homogenize(
#     data=[array(['2024-07-20T10:26:00.000000000', '2024-07...:29:00.000000000'],
#       dtype='datetime64[ns]'), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.99, 66547.99, 66547.99]), array([66541.99, 66541.99, 66541.99, ..., 66547.98, 66547.98, 66547.98]), array([66542.  , 66542.  , 66542.  , ..., 66547.98, 66547.98, 66547.98])],
#     index=RangeIndex(start=0, stop=1001, step=1),
#     dtype=None
# )
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#         val = array(['2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', ..., '2024-07-20T10:29:00.000000000',
#        '2024-07-20T10:29:00.000000000', '2024-07-20T10:29:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=1001, step=1)
#         com = <module 'pandas.core.common' from 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\core\\common.py'>
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(
#     data=array(['2024-07-20T10:26:00.000000000', '2024-07...:29:00.000000000'],
#       dtype='datetime64[ns]'),
#     index=RangeIndex(start=0, stop=1001, step=1)
# )
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#         data = array(['2024-07-20T10:26:00.000000000', '2024-07-20T10:26:00.000000000',
#        '2024-07-20T10:26:00.000000000', ..., '2024-07-20T10:29:00.000000000',
#        '2024-07-20T10:29:00.000000000', '2024-07-20T10:29:00.000000000'],
#       dtype='datetime64[ns]')
#         index = RangeIndex(start=0, stop=1001, step=1)
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (1000) does not match length of index (1001)
